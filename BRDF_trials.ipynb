# %%
cd ~/Data/goniometer/
# Out:
# /Users/maye/Data/goniometer

# %% [markdown]
# #### Notice the code high-lighting

# %%
import pandas

# %%
df = pandas.load("brdf_dataframe.pandas")

# %%
df.columns
# Out:
# Index([Incidence, Emergence, Azimuth, Reflectance], dtype=object)

# %%
df
# Out:
# <class 'pandas.core.frame.DataFrame'>Int64Index: 1631 entries, 0 to 1630Data columns:Incidence      1631  non-null valuesEmergence      1631  non-null valuesAzimuth        1631  non-null valuesReflectance    1631  non-null valuesdtypes: float64(4)

# %%
df.index
# Out:
# Int64Index([   0,    1,    2, ..., 1628, 1629, 1630], dtype=int64)

# %% [markdown]
# #### Data column names become automatically structure variables (more precisely: object attribute) and can be used for data selection:

# %%
azi_0 = df[df.Azimuth == 0]

# %%
multi_index = df.set_index(['Azimuth','Incidence','Emergence'])

# %%
multi_index.plot()

# %%
display(gcf())

# %%
s = pandas.Series(range(5),index=['a','b','c','d','e'])

# %%
s2 = pandas.Series(range(3),index=['a','b','c'])

# %%
df = pandas.DataFrame(randn(10,4),columns=['A','B','C','D'])

# %%
df - df.ix[0]
# Out:
#           A         B         C         D0  0.000000  0.000000  0.000000  0.0000001  3.651243 -1.607865  0.342786  1.6828732  0.244124 -1.958018  1.521949  1.4761173  2.268530  1.274363 -1.344908  2.1451944  3.298363 -1.233669  2.998835  0.0059195  2.737329 -1.513043  0.671326  1.5251646  1.685835  0.708997  1.427350  2.0766007  2.232877 -1.213622 -0.929703 -0.8079898  1.982665  0.139076  1.050558  1.3005929  1.951284  0.780312  0.962268 -0.466066

# %%
df
# Out:
#           A         B         C         D0 -2.230682  0.666441 -0.259594 -0.3563491  1.420561 -0.941424  0.083192  1.3265242 -1.986558 -1.291577  1.262355  1.1197683  0.037848  1.940804 -1.604502  1.7888454  1.067681 -0.567228  2.739241 -0.3504315  0.506647 -0.846602  0.411732  1.1688156 -0.544846  1.375437  1.167756  1.7202517  0.002195 -0.547181 -1.189297 -1.1643388 -0.248017  0.805517  0.790964  0.9442429 -0.279398  1.446753  0.702674 -0.822415
