# %%
cd ~/data/hirise/inca/
# Out:
# /Users/maye/data/hirise/inca

# %%
import gdal

# %%
ds = gdal.Open('4_slopes.png')

# %%
slopes = ds.ReadAsArray()

# %%
gray()

# %%
imshow(slopes)
display(gcf())

# %%
slope_map = gdal.Open('4_slopes_sloped.tif').ReadAsArray()

# %%
slope_map[slope_map <0] = np.nan

# %%
imshow(slope_map)
display(gcf())

# %%
print slope_map[100,100]
print slope_map[450, 100]
print slope_map[100,450]
print slope_map[450,450]
# Out:
# 45.0
# 45.0
# 45.0
# 45.0

# %%
aspect_map = gdal.Open('./4_slopes_aspect.tif').ReadAsArray()

# %%
aspect_map[aspect_map < 0 ] = np.nan

# %%
imshow(aspect_map)
display(gcf())

# %%
print aspect_map[100,100]
print aspect_map[100,450]
print aspect_map[450,100]
print aspect_map[450,450]
# Out:
# 0.0
# 180.0
# 270.0
# 90.0
