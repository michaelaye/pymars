# %%
from osgeo import gdal
from scipy import ndimage as nd
median = nd.filters.median_filter

# %%
cd /raid1/maye/hirise/dem
# Out:
# /raid1/maye/hirise/dem

# %%
ds = gdal.Open("DTEPC_022699_0985_022607_0985_A01.IMG")

# %%
ds.RasterXSize
# Out:
# 12767

# %%
data = ds.ReadAsArray()

# %%
data.shape
# Out:
# (6985, 12767)

# %%
data[data < 0] = np.nan

# %%
med11 = median(data,11)

# %%
med101 = median(data,101)

# %%
size = 201
l = []
for i in range(len(data)-size):
    l.append(np.median(data[i:i+size]))
plot(l)

# %%
for size in [3,11,101]:
    res = data - median(data, size)
    plot(res, label=str(size))
legend(loc='best')
